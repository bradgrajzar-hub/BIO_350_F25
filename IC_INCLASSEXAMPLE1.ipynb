# %%
def N_exp(N_0, p, time): 
    # Exponential growth model
    # Save N_values into a list
    N_values = [N_0] 
    # Save initial population
    current_N = N_0 
    for _ in range(time):
        current_N = current_N + p * current_N 
        # rund to 3 decimal places 
        current_N = round(current_N, 3)
        N_values.append(current_N) 
    return N_values

# %%
#Run the function with 35days and p = 0.4 with an initial population of 0.01
result = N_exp(0.01, 0.4, 35)
print(result)
# Out:
# [0.01, 0.014, 0.02, 0.028, 0.039, 0.055, 0.077, 0.108, 0.151, 0.211, 0.295, 0.413, 0.578, 0.809, 1.133, 1.586, 2.22, 3.108, 4.351, 6.091, 8.527, 11.938, 16.713, 23.398, 32.757, 45.86, 64.204, 89.886, 125.84, 176.176, 246.646, 345.304, 483.426, 676.796, 947.514, 1326.52]

# %%
# Plot the results with days on the x-axis and population size on the y-axis
import matplotlib.pyplot as plt
days = list(range(36))  # 0 to 35 days
plt.plot(days, result, marker='o')
plt.xlabel('Days')
plt.ylabel('Duckweed Population Size')
plt.title('Duckweed Population Growth Over Time')
plt.grid()
plt.show()

# %%
#Log the y-axis variable

import matplotlib.pyplot as plt
import numpy as np

days = list(range(36))  
log_result = np.log(result)  

plt.plot(days, log_result, marker='o')
plt.xlabel('Days')
plt.ylabel('Duckweed Population Size')
plt.title('Duckweed Population Growth Over Time')
plt.grid()
plt.show()

# %%
#Change N_Exp to N_exp2 and have 3 conditions based on N_0 
#If N_0 < 500, p = 0.4
#If N_0 >= 500 and N_0 < 1500, p = 0.2
#If N_0 >= 1000, p = 0 

def N_exp2(N_0, time):      
    # Exponential growth model with variable p based on N_0
    # Save N_values into a list
    N_values = [N_0] 
    # Save initial population
    current_N = N_0 
    for _ in range(time):
        if current_N < 500:
            p = 0.4
        elif 500 <= current_N < 1000:
            p = 0.2
        else:
            p = 0
        current_N = current_N + p * current_N 
        # rund to 3 decimal places 
        current_N = round(current_N, 3)
        N_values.append(current_N) 
    return N_values

# %%
#Run the function with 35 days and p = 0.4 with an initial population of 0.01
result = N_exp2(1, 35)
print(result)
# Out:
# [1, 1.4, 1.96, 2.744, 3.842, 5.379, 7.531, 10.543, 14.76, 20.664, 28.93, 40.502, 56.703, 79.384, 111.138, 155.593, 217.83, 304.962, 426.947, 597.726, 717.271, 860.725, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87, 1032.87]

# %%
# Plot the results with days on the x-axis and population size on the y-axis
import matplotlib.pyplot as plt
days = list(range(36))  # 0 to 35 days
plt.plot(days, result, marker='o')
plt.xlabel('Days')
plt.ylabel('Duckweed Population Size')
plt.title('Duckweed Population Growth Over Time')
plt.grid()
plt.show()
